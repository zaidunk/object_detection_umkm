# %% [markdown]
# ### Clone repository ultralytics

# %%
# git clone https://github.com/ultralytics/yolov5.git

# %% [markdown]
# ### Make new enviroment using anaconda

# %%
# conda create -n yolov5 python=3.9 -y
# conda activate yolov5

# %% [markdown]
# ### Instal pytorch cuda for training using GPU

# %%
# pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# ### Install dependencies

# %%
# pip install -r requirements.txt
# cd yolov5

# %% [markdown]
# ### Train model YoloV5

# %%
# python train.py --img 640 --batch 16 --epochs 50 --data datasets/data.yaml --weights yolov5s.pt --device 0 --freeze 10 --patience 10

# %% [markdown]
# ### Result

# %%
import pandas as pd
results_path = "YOLOv5/yolov5/runs/train/exp14"
history = pd.read_csv(results_path + "/results.csv")

# %%
history.tail(5)
# Out:
#                   epoch        train/box_loss        train/obj_loss  \
# 5                     5              0.057529              0.044599
# 6                     6              0.056907              0.044213
# 7                     7              0.056477              0.044139
# 8                     8              0.056157              0.044113
# 9                     9              0.055819              0.044241
#
#          train/cls_loss     metrics/precision        metrics/recall  \
# 5                     0               0.72193               0.50696
# 6                     0               0.72892               0.51514
# 7                     0               0.73064               0.52382
# 8                     0               0.74016               0.52586
# 9                     0               0.74078               0.53146
#
#         metrics/mAP_0.5  metrics/mAP_0.5:0.95          val/box_loss  \
# 5               0.59666               0.28240              0.050159
# ...

# %%
from IPython.display import Image, display
image_path = results_path + '/results.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/confusion_matrix.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/F1_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/P_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/PR_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/R_curve.png'

display(Image(filename=image_path, width=800, height=600))
